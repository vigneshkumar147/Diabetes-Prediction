# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshkumar147/Diabetes-Prediction/blob/main/sample_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyspark
# Out:
# ...
#      |████████████████████████████████| 281.4 MB 33 kB/s
# ...
#      |████████████████████████████████| 198 kB 59.6 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.2.1-py2.py3-none-any.whl size=281853642 sha256=63f2da58ff629f5c4f3fadd4b762a00177aa961c457370c8a0a03fad02af5fc9
#   Stored in directory: /root/.cache/pip/wheels/9f/f5/07/7cd8017084dce4e93e84e92efd1e1d5334db05f2e83bcef74f
# Successfully built pyspark
# ...

# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Project_progress").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://3f4b4357bc27:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Project_progress</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
Data_Folder = {"df1":"1.fa","df2":"2.fa","df3":"3.fa","df4":"4.fa","df5":"5.fa","df6":"6.fa","df7":"7.fa","df8":"8.fa","df9":"9.fa","df10":"10.fa","df11":"11.fa","df12":"12.fa","d13":"13.fa","df14":"14.fa","df15":"15.fa","df16":"16.fa","df17":"17.fa","df18":"18.fa","df19":"19.fa","df20":"20.fa","df21":"21.fa","df22":"22.fa","df23":"X.fa","df24":"Y.fa","df25":"MT.fa"}
def init_data():
    Data_Store=[]
    for i in Data_Folder:
        i = spark.read.csv("{}".format(Data_Folder[i]),header=True, inferSchema=True)
        Data_Store.append(i)
    return Data_Store

# %%
Data_Base = init_data()

# %%
for i in Data_Base:
    print(i.show(),i.printSchema())
# Out:
# +-------------------------------------------------------+
# |>1 dna:chromosome chromosome:GRCh37:1:1:249250621:1 REF|
# +-------------------------------------------------------+
# |                                   NNNNNNNNNNNNNNNNN...|
# |                                   NNNNNNNNNNNNNNNNN...|
# |                                   NNNNNNNNNNNNNNNNN...|
# |                                   NNNNNNNNNNNNNNNNN...|
# |                                   NNNNNNNNNNNNNNNNN...|
# |                                   NNNNNNNNNNNNNNNNN...|
# |                                   NNNNNNNNNNNNNNNNN...|
# |                                   NNNNNNNNNNNNNNNNN...|
# |                                   NNNNNNNNNNNNNNNNN...|
# |                                   NNNNNNNNNNNNNNNNN...|
# |                                   NNNNNNNNNNNNNNNNN...|
# |                                   NNNNNNNNNNNNNNNNN...|
# |                                   NNNNNNNNNNNNNNNNN...|
# ...

# %%
df = spark.read.csv('Genes.csv',header=True,inferSchema=True)
df.show()
# Out:
# +-----------+------------+
# |UniqueGenes|DomainLength|
# +-----------+------------+
# |      PSMD1|        1348|
# |      HIPK4|        1196|
# |      PRPF4|        1117|
# |      AGFG2|        1073|
# |     ATP11C|        1071|
# |      NAA20|        1047|
# |        FLG|         998|
# |       FMO1|         998|
# |       MZT1|         998|
# |      RNF14|         977|
# |  GABARAPL1|         892|
# |     MRPL49|         886|
# |      TMTC4|         886|
# |      GLOD4|         855|
# |      ASCL2|         831|
# |      MRPS2|         816|
# |      CXCL5|         799|
# |     UNC13C|         797|
# |       BYSL|         784|
# |      AZIN1|         784|
# +-----------+------------+
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- UniqueGenes: string (nullable = true)
#  |-- DomainLength: integer (nullable = true)

# %%
type(df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
import random 
def random_Generation():
  l = ["A","T","G","C"]
  for i in range(1,260000):
    a = []
    len()

# %%
import pandas as pd

# %%
pd.read_html("https://www.ncbi.nlm.nih.gov/clinvar/?term=ESPL1%5Bgene%5D&redir=gene")
# Out:
# [        VariationLocation                                VariationLocation.1  \
#  0    Select item 1507401.  GRCh38/hg38 12p13.33-q24.33(chr12:121271-13319...
#  1    Select item 1489682.  GRCh38/hg38 12q13.13(chr12:52851850-53558824)x...
#  2     Select item 590173.  GRCh38/hg38 12q13.13(chr12:53099658-53724525)x...
#  3     Select item 590184.  GRCh38/hg38 12q13.13(chr12:53224024-54222450)x...
#  4    Select item 7329915.  NM_012291.5(ESPL1):c.1787G>A (p.Arg596Gln)GRCh...
#  5    Select item 7786416.  NM_012291.5(ESPL1):c.2753A>G (p.Asn918Ser)GRCh...
#  6    Select item 7810747.  NM_012291.5(ESPL1):c.2907G>A (p.Ser969=)GRCh37...
#  7    Select item 7137628.  NM_012291.5(ESPL1):c.4010G>T (p.Gly1337Val)GRC...
#  8    Select item 7825599.  NM_012291.5(ESPL1):c.4384G>A (p.Ala1462Thr)GRC...
#  9   Select item 73299210.  NM_012291.5(ESPL1):c.4435A>G (p.Arg1479Gly)GRC...
#  10  Select item 76982311.  NM_012291.5(ESPL1):c.4463T>A (p.Ile1488Asn)GRC...
# ...
